# %%
import matplotlib.pyplot as plt

# Create a figure and axes
fig, ax = plt.subplots()

# Create a pie chart
ax.pie([0.25, 0.25, 0.25], labels=['Red', 'Green', 'Blue'], colors=['red', 'green', 'blue'])

# Show the plot
plt.show()
